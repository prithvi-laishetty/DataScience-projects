# %%
#Storing the type of recharge
recharge_type =  {"1":"Prepaid", "2":"Postpaid"}

#Storing the Payment Method
payment_type = {"1":"Credit Card","2":"Debit Card","3":"UPI","4":"Net Banking","5":"Cash"}
    
#Prepaid recharge Types
prepaid_type ={"1":"Full Recharge","2":"Talk Time","3":"Data Packs"}
    
    

#Input customer Details
#Strip() is used to remove the whitespace from both the ends

customer_name = input("Please Enter Your Name: ").strip()

while (True):
    phone=input("Enter the phone number: ")
    if phone.isnumeric and len(phone) == 10:
        break
    elif len(phone) != 10 or phone.isnumeric == false:#if the number is invalid or not numeric ask to enter again.
        print("Invalid phone number. Please enter again")
    else:
        break
     
    #print the recharge types
print("Enter the recharge type: ")
for recharge in recharge_type:
        print(recharge, ":", recharge_type[recharge])
while (True):
        type=input("Please enter the recharge type:")
        if type in recharge_type:
            break
        else:
            print("Invalid Recharge type. Please enter again:")

        
if(type == list(recharge_type.keys())[0]):
    #Storing the circle_id in cirlces key values
    circle = {"1": "Andhra Pradesh & Telangana", "2": "Assam", "3": "Bihar & Jharkhand", "4": "Delhi",
                    "5": "Gujrat", "6": "Himachal Pradesh", "7": "Haryana",
                    "8": "Jammu and Kashmir", "9": "Kerela and Lakshadweep", "10": "Karnataka", "11": "Kolkata",
                    "12": "Maharashtra and Goa",
                    "13": "Madhya Pradesh and Chhattisgarh", "14": "Mumbai", "15": "North East", "16": "Orissa",
                    "17": "Punjab", "18": "Rajasthan", "19": "Tamil Nadu", "20": "UP (East)",
                    "21": "UP (West)", "22": "West Bengal", "23": "Ghaziabad and Noida"}
    

    print("Please select the circle id from the given options: ")#display the available cirlces
    for key in circle :
            print(key,":",circle[key])
    while (True):
            c = input("Enter the circle:")
            if (c in circle) : #check if the user given the proper circle
                break
            elif (c not in circle):
                print("Invalid entry. Please enter again")
            else:
                break
        
        #storing the differet prepaid recharge types in a dictionary with key:value pairs
        #prepaid_type ={"1":"Full Recharge","2":"Talk Time","3":"Data Packs"}
    data_packs = {"1":{"250" : 'Unlimited calls(local/national) + 1.5GB data/day + 100 SMS/ day. Val = 28 days',
                    '400':'Unlimited calls(local/national) + 3 GB data/day + 100 SMS/ day. Val = 28 days',
                    '450':'Unlimited calls(local/national) + 1.5GB data/day + 100 SMS/ day. Val = 56 days',
                    '500':'Unlimited calls(local/national) + 1.5GB data/day + 100 SMS/ day. Val = 70 days',
                    '550':'Unlimited calls(local/national) + 1.5GB data/day + 100 SMS/ day. Val = 77days' },
             "2":{'100':'Talktime: Rs. 82  Val = 28 days',
                    '50':'Talktime: Rs. 39  Val = 28 days',
                    '30':'Talktime: Rs. 22  Val = 28 days',
                    '20':'Talktime: Rs. 14  Val = 28 days',
                    '10':'Talktime: Rs. 7  Val = 28 days'},
             "3":{'1200' : '240 GB data Val= 240 days',
                    '600':'72 GB data Val= 70 days',
                    '250':'50 GB data Val= 28 days',
                    '100':'12 GB data Val= 28 days',
                    '50':'6 GB data Val= 28 days'}}
    
    #chossing the prepaid type of recharge,recharge amount and amount payment
    #choose the prepaid type of recharge
    print("Please enter the Prepaid type of recharge:")
    for key in prepaid_type:
        print(key,":",prepaid_type[key])

    while (True):
        recharge_type =input("Please enter the Prepaid type of recharge: ")
        if(recharge_type in data_packs.keys()):
            for inner_key in data_packs[recharge_type].keys():#access the inner key of the nested dictionary
                print(inner_key,":",data_packs[recharge_type][inner_key])#dispaly the available pack amount to the user
                pack_details = data_packs[recharge_type][inner_key]#stores the pack details
            break
        elif(recharge_type not in data_packs.keys()):
            print("Invalid entered by user. Enter again")
        else:
                break
                
    #choosing the recharge amount
    while(True):
        recharge_amount = input("Enter the amount of recharge: ")#input the amount in integer format
        if(recharge_amount in data_packs[recharge_type].keys()): #check if valid input is given or not
            break
        elif(recharge_amount not in data_packs[recharge_type].keys()):
            print("Invalid amount. please enter again ")
        else:
            break
            
    print("please enter the transaction method:")      
    
    #choosing the payment type or transaction method
    for i in payment_type.keys():
        print(i,":",payment_type[i])#display the available payment type
    while True:
        trans_mode = input("please enter the payment method: ")
        if(trans_mode in payment_type.keys()):
            print("Transaction was successful:")
            break
        elif(trans_mode not in payment_type.keys()):
            print("Invalid payment method. please try again: ")
        else:
            break
        
        
    print("Here is your prepaid mobile recharge bill")
    print("*********************************")
    print("Name of customer:", customer_name)
    print("Mobile Number:",phone)
    print("Circle Name:", circle[c])
    print("Recharge type:",prepaid_type[recharge_type])
    print("Recharge pack details:",pack_details)
    print("Transaction method: ",payment_type[trans_mode])
    print("pack amount:Rs",recharge_amount)
    print("GST : 18%")
    print("*********************************")
    print("---------------------------------")
    print("Total Bill: Rs", int(recharge_amount)*(1+0.18))
    print("---------------------------------")


else:
    postpaid = int(input("Enter the amount: "))
    #choosing the payment method
    for i in payment_type.keys():
        print(i,":", payment_type[i])#display the available payment types given in the list
    while(True):
        trans_mode = input("Enter the payment method: ")
        if(trans_mode in payment_type.keys()):
            print("Transaction was successful:")
            break
        elif(trans_mode not in payment_type.keys()):
            print("Invalid Input. Enter again: ")
        else:
            break
            
    print("Here is your postpaid mobile recharge bill")
    print("*********************************")
    print("Name of customer:", customer_name)
    print("Mobile Number:",phone)
    print("Transaction method: ",payment_type[trans_mode])
    print("Postpaid Bill: Rs",postpaid)
    print("GST : 18%")
    print("*********************************")
    print("---------------------------------")
    print("Total Bill: Rs", int(postpaid)*(1+0.18))
    print("---------------------------------")
# Out:
# Please Enter Your Name: Ravi Siddappareddy
# Enter the phone number: 9625384645
# Enter the recharge type:
# 1 : Prepaid
# 2 : Postpaid
# Please enter the recharge type:2
# Enter the amount: 450
# 1 : Credit Card
# 2 : Debit Card
# 3 : UPI
# 4 : Net Banking
# 5 : Cash
# Enter the payment method: 4
# Transaction was successful:
# Here is your postpaid mobile recharge bill
# *********************************
# Name of customer: Ravi Siddappareddy
# Mobile Number: 9625384645
# Transaction method:  Net Banking
# Postpaid Bill: Rs 450
# GST : 18%
# *********************************
# ---------------------------------
# Total Bill: Rs 531.0
# ---------------------------------
